# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]

# %%
matches
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1   2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2   2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3   2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4   2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
# 5   2022-08-31  19:30    Premier League          Matchweek 5  Wed     Home
# 6   2022-09-03  17:30    Premier League          Matchweek 6  Sat     Away
# 7   2022-09-06  21:00      Champions Lg          Group stage  Tue     Away
# 8   2022-09-10  17:30    Premier League          Matchweek 7  Sat     Home
# 9   2022-09-14  20:00      Champions Lg          Group stage  Wed     Home
# 10  2022-09-17  12:30    Premier League          Matchweek 8  Sat     Away
# 11  2022-10-02  14:00    Premier League          Matchweek 9  Sun     Home
# 12  2022-10-05  20:00      Champions Lg          Group stage  Wed     Home
# 13  2022-10-08  15:00    Premier League         Matchweek 10  Sat     Home
# 14  2022-10-11  18:45      Champions Lg          Group stage  Tue     Away
# 15  2022-10-16  16:30    Premier League         Matchweek 11  Sun     Away
# 16  2022-10-19  19:30    Premier League         Matchweek 12  Wed     Away
# 17  2022-10-22  15:00    Premier League         Matchweek 13  Sat     Home
# 18  2022-10-25  21:00      Champions Lg          Group stage  Tue     Away
# 19  2022-10-29  12:30    Premier League         Matchweek 14  Sat     Away
# 20  2022-11-02  20:00      Champions Lg          Group stage  Wed     Home
# 21  2022-11-05  15:00    Premier League         Matchweek 15  Sat     Home
# 22  2022-11-09  20:00           EFL Cup          Third round  Wed     Home
# 23  2022-11-12  12:30    Premier League         Matchweek 16  Sat     Home
# 24  2022-12-28  20:00    Premier League         Matchweek 17  Wed     Away
# 25  2022-12-31  15:00    Premier League         Matchweek 18  Sat     Home
# 26  2023-01-05  20:00    Premier League         Matchweek 19  Thu     Away
# 27  2023-01-14  15:00    Premier League         Matchweek 20  Sat     Away
# 28  2023-01-21  15:00    Premier League         Matchweek 21  Sat     Home
# 29  2023-02-04  15:00    Premier League         Matchweek 22  Sat     Away
# 30  2023-02-11  15:00    Premier League         Matchweek 23  Sat     Home
# 31  2023-02-18  15:00    Premier League         Matchweek 24  Sat     Away
# 32  2023-02-25  15:00    Premier League         Matchweek 25  Sat     Away
# 33  2023-03-04  15:00    Premier League         Matchweek 26  Sat     Home
# 34  2023-03-11  15:00    Premier League         Matchweek 27  Sat     Away
# 35  2023-03-18  15:00    Premier League         Matchweek 28  Sat     Home
# 36  2023-04-01  15:00    Premier League         Matchweek 29  Sat     Home
# 37  2023-04-08  15:00    Premier League         Matchweek 30  Sat     Away
# 38  2023-04-15  15:00    Premier League         Matchweek 31  Sat     Home
# 39  2023-04-22  15:00    Premier League         Matchweek 32  Sat     Away
# 40  2023-04-26  20:00    Premier League         Matchweek 33  Wed     Home
# 41  2023-04-29  15:00    Premier League         Matchweek 34  Sat     Away
# 42  2023-05-06  15:00    Premier League         Matchweek 35  Sat     Home
# 43  2023-05-13  15:00    Premier League         Matchweek 36  Sat     Away
# 44  2023-05-20  15:00    Premier League         Matchweek 37  Sat     Home
# 45  2023-05-28  15:00    Premier League         Matchweek 38  Sun     Away
#
#    Result   GF   GA          Opponent   xG  xGA  Poss  Attendance  \
# 0       L  1.0  3.0         Liverpool  NaN  NaN  57.0         NaN
# 1       W  2.0  0.0          West Ham  2.2  0.5  75.0     62443.0
# 2       W  4.0  0.0       Bournemouth  1.7  0.1  67.0     53453.0
# 3       D  3.0  3.0     Newcastle Utd  2.1  1.8  69.0     52258.0
# 4       W  4.0  2.0    Crystal Palace  2.2  0.1  74.0     53112.0
# 5       W  6.0  0.0   Nott'ham Forest  3.3  0.7  74.0     53409.0
# 6       D  1.0  1.0       Aston Villa  2.1  0.3  71.0     41830.0
# 7       W  4.0  0.0        es Sevilla  3.6  0.3  61.0     38764.0
# 8     NaN  NaN  NaN         Tottenham  NaN  NaN   NaN         NaN
# 9       W  2.0  1.0       de Dortmund  1.0  0.7  66.0     50441.0
# 10      W  3.0  0.0            Wolves  1.1  0.4  59.0     31578.0
# 11      W  6.0  3.0    Manchester Utd  3.2  1.7  53.0     53475.0
# 12      W  5.0  0.0  dk FC Copenhagen  4.3  0.4  75.0     51765.0
# 13      W  4.0  0.0       Southampton  2.2  0.1  66.0     53365.0
# 14      D  0.0  0.0  dk FC Copenhagen  1.5  0.3  59.0     35447.0
# 15      L  0.0  1.0         Liverpool  0.9  2.0  63.0     53286.0
# 16    NaN  NaN  NaN           Arsenal  NaN  NaN   NaN         NaN
# 17      W  3.0  1.0          Brighton  1.9  0.4  47.0     53223.0
# 18      D  0.0  0.0       de Dortmund  1.2  1.1  73.0     81000.0
# 19      W  1.0  0.0    Leicester City  1.0  0.7  64.0     32223.0
# 20    NaN  NaN  NaN        es Sevilla  NaN  NaN   NaN         NaN
# 21    NaN  NaN  NaN            Fulham  NaN  NaN   NaN         NaN
# 22    NaN  NaN  NaN           Chelsea  NaN  NaN   NaN         NaN
# 23    NaN  NaN  NaN         Brentford  NaN  NaN   NaN         NaN
# 24    NaN  NaN  NaN      Leeds United  NaN  NaN   NaN         NaN
# 25    NaN  NaN  NaN           Everton  NaN  NaN   NaN         NaN
# 26    NaN  NaN  NaN           Chelsea  NaN  NaN   NaN         NaN
# 27    NaN  NaN  NaN    Manchester Utd  NaN  NaN   NaN         NaN
# 28    NaN  NaN  NaN            Wolves  NaN  NaN   NaN         NaN
# 29    NaN  NaN  NaN         Tottenham  NaN  NaN   NaN         NaN
# 30    NaN  NaN  NaN       Aston Villa  NaN  NaN   NaN         NaN
# 31    NaN  NaN  NaN   Nott'ham Forest  NaN  NaN   NaN         NaN
# 32    NaN  NaN  NaN       Bournemouth  NaN  NaN   NaN         NaN
# 33    NaN  NaN  NaN     Newcastle Utd  NaN  NaN   NaN         NaN
# 34    NaN  NaN  NaN    Crystal Palace  NaN  NaN   NaN         NaN
# 35    NaN  NaN  NaN          West Ham  NaN  NaN   NaN         NaN
# 36    NaN  NaN  NaN         Liverpool  NaN  NaN   NaN         NaN
# 37    NaN  NaN  NaN       Southampton  NaN  NaN   NaN         NaN
# 38    NaN  NaN  NaN    Leicester City  NaN  NaN   NaN         NaN
# 39    NaN  NaN  NaN          Brighton  NaN  NaN   NaN         NaN
# 40    NaN  NaN  NaN           Arsenal  NaN  NaN   NaN         NaN
# 41    NaN  NaN  NaN            Fulham  NaN  NaN   NaN         NaN
# 42    NaN  NaN  NaN      Leeds United  NaN  NaN   NaN         NaN
# 43    NaN  NaN  NaN           Everton  NaN  NaN   NaN         NaN
# 44    NaN  NaN  NaN           Chelsea  NaN  NaN   NaN         NaN
# 45    NaN  NaN  NaN         Brentford  NaN  NaN   NaN         NaN
#
#             Captain Formation         Referee  Match Report            Notes
# 0        Rúben Dias     4-3-3    Craig Pawson  Match Report              NaN
# 1    İlkay Gündoğan     4-3-3  Michael Oliver  Match Report              NaN
# 2    İlkay Gündoğan   4-2-3-1     David Coote  Match Report              NaN
# 3    İlkay Gündoğan     4-3-3  Jarred Gillett  Match Report              NaN
# 4   Kevin De Bruyne   4-2-3-1  Darren England  Match Report              NaN
# 5    İlkay Gündoğan   4-2-3-1    Paul Tierney  Match Report              NaN
# 6    İlkay Gündoğan     4-3-3    Simon Hooper  Match Report              NaN
# 7   Kevin De Bruyne     4-3-3    Davide Massa  Match Report              NaN
# 8               NaN       NaN             NaN           NaN  Match Postponed
# 9    İlkay Gündoğan     4-3-3  Daniele Orsato  Match Report              NaN
# 10  Kevin De Bruyne     4-3-3  Anthony Taylor  Match Report              NaN
# 11   İlkay Gündoğan     4-3-3  Michael Oliver  Match Report              NaN
# 12   İlkay Gündoğan     4-4-2  Donatas Rumšas  Match Report              NaN
# 13  Kevin De Bruyne   4-2-3-1     Andy Madley  Match Report              NaN
# 14   İlkay Gündoğan   4-2-3-1      Artur Dias  Match Report              NaN
# 15   İlkay Gündoğan     3-4-3  Anthony Taylor  Match Report              NaN
# 16              NaN       NaN             NaN           NaN  Match Postponed
# 17  Kevin De Bruyne     4-3-3    Craig Pawson  Match Report              NaN
# 18   İlkay Gündoğan     4-4-2    Davide Massa  Match Report              NaN
# 19   İlkay Gündoğan     4-3-3    Robert Jones  Match Report              NaN
# 20              NaN       NaN             NaN  Head-to-Head              NaN
# 21              NaN       NaN             NaN  Head-to-Head              NaN
# 22              NaN       NaN             NaN  Head-to-Head              NaN
# 23              NaN       NaN             NaN  Head-to-Head              NaN
# 24              NaN       NaN             NaN  Head-to-Head              NaN
# 25              NaN       NaN             NaN  Head-to-Head              NaN
# 26              NaN       NaN             NaN  Head-to-Head              NaN
# 27              NaN       NaN             NaN  Head-to-Head              NaN
# 28              NaN       NaN             NaN  Head-to-Head              NaN
# 29              NaN       NaN             NaN  Head-to-Head              NaN
# 30              NaN       NaN             NaN  Head-to-Head              NaN
# 31              NaN       NaN             NaN  Head-to-Head              NaN
# 32              NaN       NaN             NaN  Head-to-Head              NaN
# 33              NaN       NaN             NaN  Head-to-Head              NaN
# 34              NaN       NaN             NaN  Head-to-Head              NaN
# 35              NaN       NaN             NaN  Head-to-Head              NaN
# 36              NaN       NaN             NaN  Head-to-Head              NaN
# 37              NaN       NaN             NaN  Head-to-Head              NaN
# 38              NaN       NaN             NaN  Head-to-Head              NaN
# 39              NaN       NaN             NaN  Head-to-Head              NaN
# 40              NaN       NaN             NaN  Head-to-Head              NaN
# 41              NaN       NaN             NaN  Head-to-Head              NaN
# 42              NaN       NaN             NaN  Head-to-Head              NaN
# 43              NaN       NaN             NaN  Head-to-Head              NaN
# 44              NaN       NaN             NaN  Head-to-Head              NaN
# 45              NaN       NaN             NaN  Head-to-Head              NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Manchester City                                                     \
#                  Date   Time              Comp                Round  Day
# 0          2022-07-30  17:00  Community Shield  FA Community Shield  Sat
# 1          2022-08-07  16:30    Premier League          Matchweek 1  Sun
# 2          2022-08-13  15:00    Premier League          Matchweek 2  Sat
# 3          2022-08-21  16:30    Premier League          Matchweek 3  Sun
# 4          2022-08-27  15:00    Premier League          Matchweek 4  Sat
#
#                                          ... Standard               Expected  \
#      Venue Result GF GA        Opponent  ...     Dist   FK PK PKatt       xG
# 0  Neutral      L  1  3       Liverpool  ...      NaN  NaN  0     0      NaN
# 1     Away      W  2  0        West Ham  ...     18.7  1.0  1     1      2.2
# 2     Home      W  4  0     Bournemouth  ...     17.5  0.0  0     0      1.7
# 3     Away      D  3  3   Newcastle Utd  ...     16.2  1.0  0     0      2.1
# 4     Home      W  4  2  Crystal Palace  ...     14.1  0.0  0     0      2.2
#
#                             Unnamed: 25_level_0
#   npxG npxG/Sh G-xG np:G-xG        Match Report
# 0  NaN     NaN  NaN     NaN        Match Report
# 1  1.4    0.11 -0.2    -0.4        Match Report
# 2  1.7    0.09  1.3     1.3        Match Report
# 3  2.1    0.10  0.9     0.9        Match Report
# 4  2.2    0.13  1.8     1.8        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2022-07-30  17:00  Community Shield  FA Community Shield  Sat  Neutral
# 1  2022-08-07  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2022-08-13  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2022-08-21  16:30    Premier League          Matchweek 3  Sun     Away
# 4  2022-08-27  15:00    Premier League          Matchweek 4  Sat     Home
#
#   Result   GF   GA        Opponent  ...  Formation         Referee  \
# 0      L  1.0  3.0       Liverpool  ...      4-3-3    Craig Pawson
# 1      W  2.0  0.0        West Ham  ...      4-3-3  Michael Oliver
# 2      W  4.0  0.0     Bournemouth  ...    4-2-3-1     David Coote
# 3      D  3.0  3.0   Newcastle Utd  ...      4-3-3  Jarred Gillett
# 4      W  4.0  2.0  Crystal Palace  ...    4-2-3-1  Darren England
#
#    Match Report  Notes  Sh SoT  Dist   FK PK  PKatt
# 0  Match Report    NaN  14   8   NaN  NaN  0      0
# 1  Match Report    NaN  13   1  18.7  1.0  1      1
# 2  Match Report    NaN  19   7  17.5  0.0  0      0
# 3  Match Report    NaN  21  10  16.2  1.0  0      0
# 4  Match Report    NaN  18   5  14.1  0.0  0      0
#
# [5 rows x 25 columns]

# %%
years = list(range(2022, 2020, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 47

# %%
match_df = pd.concat(all_matches)
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2   2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3   2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5   2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L    0
# 39  2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L    0
# 40  2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W    1
# 41  2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L    0
# 42  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W    1
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk  \
# 1   0.0         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0
# 2   0.0      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0
# 3   3.0    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0
# 4   2.0   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0
# 5   0.0  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0
# ..  ...              ...  ...           ...    ...   ...   ...   ...  ...
# 38    4        Tottenham  ...  Match Report    NaN   8.0   1.0  18.2  0.0
# 39    2   Crystal Palace  ...  Match Report    NaN   7.0   0.0  13.4  1.0
# 40    0          Everton  ...  Match Report    NaN  10.0   3.0  18.5  0.0
# 41    1    Newcastle Utd  ...  Match Report    NaN  11.0   1.0  18.3  1.0
# 42    0          Burnley  ...  Match Report    NaN  12.0   3.0  17.4  0.0
#
#      pk pkatt season              team
# 1   1.0   1.0   2022   Manchester City
# 2   0.0   0.0   2022   Manchester City
# 3   0.0   0.0   2022   Manchester City
# 4   0.0   0.0   2022   Manchester City
# 5   0.0   0.0   2022   Manchester City
# ..  ...   ...    ...               ...
# 38  0.0   0.0   2021  Sheffield United
# 39  0.0   0.0   2021  Sheffield United
# 40  0.0   0.0   2021  Sheffield United
# 41  0.0   0.0   2021  Sheffield United
# 42  0.0   0.0   2021  Sheffield United
#
# [1605 rows x 27 columns]

# %%
match_df.to_csv("games.csv")
